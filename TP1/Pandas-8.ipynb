# %% [markdown]
# **8.La mediana de la antigüedad para las últimas ediciones vigentes agrupado por el primer carácter del título (⭐⭐).**

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from datetime import datetime

# %% [markdown]
# Leo solo las columnas que necesito, solo porque ya sé como es el .csv

# %%
df_contents = pd.read_csv( "/content/drive/MyDrive/datosTP1/contents.csv", usecols=["title", "revision_timestamp"] )

# %%
df_contents.head()
# Out:
#                              title    revision_timestamp
# 0  Wikipedia:Artículos solicitados  2021-01-19T18:40:34Z
# 1                          Andorra  2021-08-31T18:27:01Z
# 2                        Argentina  2021-08-28T17:17:54Z
# 3             Geografía de Andorra  2021-08-29T17:16:00Z
# 4            Demografía de Andorra  2020-11-12T19:56:15Z

# %%
df_contents.title.isna().any()
# Out:
# True

# %%
df_contents.revision_timestamp.isna().any()
# Out:
# False

# %%
df_contents = df_contents.loc[ df_contents.title.notna() ]

# %% [markdown]
# Paso la revision_timestamp a DateTime para poder aplicarle la mediana después.

# %%
df_contents["revision_timestamp"] = pd.to_datetime( df_contents["revision_timestamp"] )

# %% [markdown]
# Agrupo según el primer carácter del título.

# %%
agrupados_por_primer_caracter = df_contents.groupby( ( df_contents["title"].str[0] ) )

# %% [markdown]
# Le aplico la mediana al "revision_timestamp" de cada conjunto groupby.

# %%
agrupados_por_primer_caracter.agg( { "revision_timestamp": ["median"] } )
# Out:
#                     revision_timestamp
#                                 median
# title
# !            2021-02-17 20:11:04+00:00
# "     2020-11-04 22:33:01.500000+00:00
# $            2021-07-29 22:46:51+00:00
# %            2021-07-03 02:47:32+00:00
# &            2020-07-18 18:53:02+00:00
# ...                                ...
# 💣            2015-10-20 06:11:01+00:00
# 🚀            2014-02-21 03:15:40+00:00
# 🧆            2019-04-01 06:44:37+00:00
# 𠆢            2021-01-17 05:00:56+00:00
# 𠘨            2021-01-17 05:59:35+00:00
#
# [1846 rows x 1 columns]
